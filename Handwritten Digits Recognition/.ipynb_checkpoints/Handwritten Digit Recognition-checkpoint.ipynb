# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline 
import numpy as np
import seaborn as sn

# %%
(x_train, y_train) , (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
plt.matshow(x_train[1])

# %%
y_train[1]
# Out:
# np.uint8(0)

# %%
x_train = x_train / 255
x_test = x_test / 255

# %%
# without hidden layer

model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)),
    keras.layers.Dense(10, activation = 'sigmoid')                      
])

model.compile(
             optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy']
)

history = model.fit(x_train, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8166 - loss: 0.7157
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9142 - loss: 0.3076
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9200 - loss: 0.2845
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9219 - loss: 0.2805
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9255 - loss: 0.2674

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9135 - loss: 0.3112
# [0.2720228433609009, 0.9240999817848206]

# %%
# Extract values
epochs = range(1, len(history.history['loss']) + 1)
train_loss = history.history['loss']
train_acc = history.history.get('accuracy', history.history.get('acc'))  # Adjust for older versions

# Plot loss and accuracy on the same graph
fig, ax1 = plt.subplots()

# Plot loss
ax1.plot(epochs, train_loss, 'r', label='Train Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Create a twin y-axis to plot accuracy
ax2 = ax1.twinx()
ax2.plot(epochs, train_acc, 'b', label='Train Accuracy')
ax2.set_ylabel('Accuracy', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Title and legend
plt.title('Accuracy and Loss over Epochs')
fig.legend(loc='upper right')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
for i in range(10):
    print("Actual Image")
    plt.matshow(x_test[i])
    plt.show()
    print("Predicted Label")
    print(y_predicted_labels[i])
    print()
# Out:
# Actual Image
# Predicted Label
# 7
#
# Actual Image
# Predicted Label
# 2
#
# Actual Image
# Predicted Label
# 1
#
# Actual Image
# Predicted Label
# 0
#
# Actual Image
# Predicted Label
# 4
#
# Actual Image
# Predicted Label
# 1
#
# Actual Image
# Predicted Label
# 4
#
# Actual Image
# Predicted Label
# 9
#
# Actual Image
# Predicted Label
# 6
#
# Actual Image
# Predicted Label
# 9

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
# using hidden layers

model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)),
    keras.layers.Dense(100, activation = 'sigmoid'),
    keras.layers.Dense(100, activation = 'sigmoid'),
    keras.layers.Dense(10, activation = 'sigmoid')                      
])

model.compile(
             optimizer = 'adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy']
)

history = model.fit(x_train, y_train, epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - accuracy: 0.7880 - loss: 0.8541
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9428 - loss: 0.1953
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9611 - loss: 0.1306
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 19s 6ms/step - accuracy: 0.9693 - loss: 0.1029
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9788 - loss: 0.0718
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - accuracy: 0.9832 - loss: 0.0579
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9855 - loss: 0.0492
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - accuracy: 0.9893 - loss: 0.0386
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9914 - loss: 0.0307
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9932 - loss: 0.0254

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9721 - loss: 0.0939
# [0.08351675420999527, 0.9753999710083008]

# %%
# Extract values
epochs = range(1, len(history.history['loss']) + 1)
train_loss = history.history['loss']
train_acc = history.history.get('accuracy', history.history.get('acc'))  # Adjust for older versions

# Plot loss and accuracy on the same graph
fig, ax1 = plt.subplots()

# Plot loss
ax1.plot(epochs, train_loss, 'r', label='Train Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='red')
ax1.tick_params(axis='y', labelcolor='red')

# Create a twin y-axis to plot accuracy
ax2 = ax1.twinx()
ax2.plot(epochs, train_acc, 'b', label='Train Accuracy')
ax2.set_ylabel('Accuracy', color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

# Title and legend
plt.title('Accuracy and Loss over Epochs')
fig.legend(loc='upper right')
plt.show()

# %%
y_predicted = model.predict(x_test)
y_predicted_labels = [np.argmax(i) for i in y_predicted]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
for i in range(10):
    print("Actual Image")
    plt.matshow(x_test[i])
    plt.show()
    print("Predicted Label")
    print(y_predicted_labels[i])
    print()
# Out:
# Actual Image
# Predicted Label
# 7
#
# Actual Image
# Predicted Label
# 2
#
# Actual Image
# Predicted Label
# 1
#
# Actual Image
# Predicted Label
# 0
#
# Actual Image
# Predicted Label
# 4
#
# Actual Image
# Predicted Label
# 1
#
# Actual Image
# Predicted Label
# 4
#
# Actual Image
# Predicted Label
# 9
#
# Actual Image
# Predicted Label
# 5
#
# Actual Image
# Predicted Label
# 9

# %%
cm = tf.math.confusion_matrix(labels=y_test,predictions=y_predicted_labels)
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')
